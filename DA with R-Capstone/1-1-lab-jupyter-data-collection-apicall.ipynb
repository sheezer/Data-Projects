# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M1_R_Basics/images/IDSNlogo.png" width="200" align="center">
# </a>

# %% [markdown]
# <h1>OpenWeather APIs Calls</h1>
#
# Estimated time needed: **40** minutes

# %% [markdown]
# ## Lab Overview:
#
# In this lab, you will be collecting real-time current and forecasted weather data for cities using the **OpenWeather API**. It can give you current weather data for any location including over 200,000 cities and 5 day forecasts for free (with limited API usage). You just need to use HTTP requests to call those weather APIs and get the weather data.
#
# You will be given instructions to set up a free OpenWeather API account with an API key for authentication. Then, you will be shown, with code examples, how to get the current weather for a given city. After you are familiar with OpenWeather API, you will be asked to get 5-day forecast data for a list of cities.

# %% [markdown]
# ## Setup OpenWeather API account

# %% [markdown]
# You can create an OpenWeather API account [here](https://home.openweathermap.org/users/sign_up?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01). After your account has been created and verified, you can go to Account -> My API Keys:

# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/l2-openweather-apikey.png" width="400" align="center">
# </a>

# %% [markdown]
# and find your API key here:

# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_1/images/l2-openweather-apikey-value.png" width="400" align="center">
# </a>

# %% [markdown]
# Now mark down your generated API key, which will be used to authenticate your HTTP requests to OpenWeather API.
#
# Note that a new API key may take some time to be activated. You may quickly try the following URL using a web browser.
#
# With the `{your_api_key}` URL parameter replaced by your own API key and go to the following URL:
#
# [https://api.openweathermap.org/data/2.5/weather?q=Seoul\&appid={your_api_key}](https://api.openweathermap.org/data/2.5/weather?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01&q=Seoul&appid=%7Byour_api_key%7D)

# %% [markdown]
# until you see some weather data returned (instead of 401 or other error status), similar to the following JSON result:
#
# ```
# {"coord":{"lon":126.9778,"lat":37.5683},
# "weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],
# "base":"stations",
# "main":{"temp":285.16,"feels_like":284.04,"temp_min":284.15,"temp_max":287.15,"pressure":1020,"humidity":62},
# "visibility":10000,
# "wind":{"speed":1.03,"deg":220},"clouds":{"all":0},"dt":1617718307,"sys":{"type":1,"id":8105,"country":"KR","sunrise":1617657021,"sunset":1617703103},"timezone":32400,"id":1835848,"name":"Seoul","cod":200}
# ```

# %% [markdown]
# ## Coding Practice: Get the current weather data for a city using OpenWeather API

# %% [markdown]
# First import `httr` library

# %%
# Check if need to install rvest` library
#require("httr")

library(httr)

# %% [markdown]
# The API base URL to get current weather is [https://api.openweathermap.org/data/2.5/weather](https://api.openweathermap.org/data/2.5/weather?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01)

# %%
# URL for Current Weather API
current_weather_url <- 'https://api.openweathermap.org/data/2.5/weather'
forecast_url <- 'https://api.openweathermap.org/data/2.5/forecast'

# %% [markdown]
# Next, let's create a list to hold URL parameters for current weather API

# %%
# need to be replaced by your real API key
city_name12 <- c("Seoul")
your_api_key <- "9948c3bde5327cfdf22d78f34c01714d"
# Input `q` is the city name
# Input `appid` is your API KEY, 
# Input `units` are preferred units such as Metric or Imperial
current_query <- list(q = city_name12, appid = your_api_key, units="metric")

# %% [markdown]
# Now we can make a HTTP request to the current weather API

# %%
response <- GET(forecast_url, query=current_query)

# %% [markdown]
# If we check the response type, we can see it is in JSON format

# %%
http_type(response)
# Out:
# [1] "application/json"

# %% [markdown]
# JSON is an open standard file and data interchange format that uses human-readable text to store and transmit data objects. To read the JSON HTTP response, you can use the `content()` function to parse it as a named list in R.

# %%
json_result <- content(response, as="parsed")

# %% [markdown]
# If you use the `class()` function, you can see it is a R `List` object

# %%
class(json_result)
# Out:
# [1] "list"

# %% [markdown]
# Now let's print the JSON result.

# %%
json_result
# Out:
# $cod
# [1] "200"
#
# $message
# [1] 0
#
# $cnt
# [1] 40
#
# $list
# $list[[1]]
# $list[[1]]$dt
# [1] 1661374800
#
# $list[[1]]$main
# $list[[1]]$main$temp
# [1] 20.82
#
# $list[[1]]$main$feels_like
# [1] 21.05
#
# $list[[1]]$main$temp_min
# [1] 20.82
#
# $list[[1]]$main$temp_max
# [1] 21.12
#
# $list[[1]]$main$pressure
# [1] 1007
#
# $list[[1]]$main$sea_level
# [1] 1007
#
# $list[[1]]$main$grnd_level
# [1] 1001
#
# $list[[1]]$main$humidity
# [1] 80
#
# $list[[1]]$main$temp_kf
# [1] -0.3
#
#
# $list[[1]]$weather
# $list[[1]]$weather[[1]]
# $list[[1]]$weather[[1]]$id
# [1] 802
#
# $list[[1]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[1]]$weather[[1]]$description
# [1] "scattered clouds"
#
# $list[[1]]$weather[[1]]$icon
# [1] "03d"
#
#
#
# $list[[1]]$clouds
# $list[[1]]$clouds$all
# [1] 29
#
#
# $list[[1]]$wind
# $list[[1]]$wind$speed
# [1] 0.77
#
# $list[[1]]$wind$deg
# [1] 117
#
# $list[[1]]$wind$gust
# [1] 0.84
#
#
# $list[[1]]$visibility
# [1] 10000
#
# $list[[1]]$pop
# [1] 0
#
# $list[[1]]$sys
# $list[[1]]$sys$pod
# [1] "d"
#
#
# $list[[1]]$dt_txt
# [1] "2022-08-24 21:00:00"
#
#
# $list[[2]]
# $list[[2]]$dt
# [1] 1661385600
#
# $list[[2]]$main
# $list[[2]]$main$temp
# [1] 22.53
#
# $list[[2]]$main$feels_like
# [1] 22.72
#
# $list[[2]]$main$temp_min
# [1] 22.53
#
# $list[[2]]$main$temp_max
# [1] 23.46
#
# $list[[2]]$main$pressure
# [1] 1008
#
# $list[[2]]$main$sea_level
# [1] 1008
#
# $list[[2]]$main$grnd_level
# [1] 1001
#
# $list[[2]]$main$humidity
# [1] 72
#
# $list[[2]]$main$temp_kf
# [1] -0.93
#
#
# $list[[2]]$weather
# $list[[2]]$weather[[1]]
# $list[[2]]$weather[[1]]$id
# [1] 803
#
# $list[[2]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[2]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[2]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[2]]$clouds
# $list[[2]]$clouds$all
# [1] 63
#
#
# $list[[2]]$wind
# $list[[2]]$wind$speed
# [1] 0.91
#
# $list[[2]]$wind$deg
# [1] 162
#
# $list[[2]]$wind$gust
# [1] 1.22
#
#
# $list[[2]]$visibility
# [1] 10000
#
# $list[[2]]$pop
# [1] 0
#
# $list[[2]]$sys
# $list[[2]]$sys$pod
# [1] "d"
#
#
# $list[[2]]$dt_txt
# [1] "2022-08-25 00:00:00"
#
#
# $list[[3]]
# $list[[3]]$dt
# [1] 1661396400
#
# $list[[3]]$main
# $list[[3]]$main$temp
# [1] 22.41
#
# $list[[3]]$main$feels_like
# [1] 22.82
#
# $list[[3]]$main$temp_min
# [1] 22.41
#
# $list[[3]]$main$temp_max
# [1] 22.41
#
# $list[[3]]$main$pressure
# [1] 1008
#
# $list[[3]]$main$sea_level
# [1] 1008
#
# $list[[3]]$main$grnd_level
# [1] 1002
#
# $list[[3]]$main$humidity
# [1] 81
#
# $list[[3]]$main$temp_kf
# [1] 0
#
#
# $list[[3]]$weather
# $list[[3]]$weather[[1]]
# $list[[3]]$weather[[1]]$id
# [1] 500
#
# $list[[3]]$weather[[1]]$main
# [1] "Rain"
#
# $list[[3]]$weather[[1]]$description
# [1] "light rain"
#
# $list[[3]]$weather[[1]]$icon
# [1] "10d"
#
#
#
# $list[[3]]$clouds
# $list[[3]]$clouds$all
# [1] 100
#
#
# $list[[3]]$wind
# $list[[3]]$wind$speed
# [1] 2.09
#
# $list[[3]]$wind$deg
# [1] 247
#
# $list[[3]]$wind$gust
# [1] 3.41
#
#
# $list[[3]]$visibility
# [1] 10000
#
# $list[[3]]$pop
# [1] 0.91
#
# $list[[3]]$rain
# $list[[3]]$rain$`3h`
# [1] 0.56
#
#
# $list[[3]]$sys
# $list[[3]]$sys$pod
# [1] "d"
#
#
# $list[[3]]$dt_txt
# [1] "2022-08-25 03:00:00"
#
#
# $list[[4]]
# $list[[4]]$dt
# [1] 1661407200
#
# $list[[4]]$main
# $list[[4]]$main$temp
# [1] 21.99
#
# $list[[4]]$main$feels_like
# [1] 21.94
#
# $list[[4]]$main$temp_min
# [1] 21.99
#
# $list[[4]]$main$temp_max
# [1] 21.99
#
# $list[[4]]$main$pressure
# [1] 1007
#
# $list[[4]]$main$sea_level
# [1] 1007
#
# $list[[4]]$main$grnd_level
# [1] 1001
#
# $list[[4]]$main$humidity
# [1] 65
#
# $list[[4]]$main$temp_kf
# [1] 0
#
#
# $list[[4]]$weather
# $list[[4]]$weather[[1]]
# $list[[4]]$weather[[1]]$id
# [1] 500
#
# $list[[4]]$weather[[1]]$main
# [1] "Rain"
#
# $list[[4]]$weather[[1]]$description
# [1] "light rain"
#
# $list[[4]]$weather[[1]]$icon
# [1] "10d"
#
#
#
# $list[[4]]$clouds
# $list[[4]]$clouds$all
# [1] 100
#
#
# $list[[4]]$wind
# $list[[4]]$wind$speed
# [1] 1.48
#
# $list[[4]]$wind$deg
# [1] 251
#
# $list[[4]]$wind$gust
# [1] 3.38
#
#
# $list[[4]]$visibility
# [1] 10000
#
# $list[[4]]$pop
# [1] 0.93
#
# $list[[4]]$rain
# $list[[4]]$rain$`3h`
# [1] 0.71
#
#
# $list[[4]]$sys
# $list[[4]]$sys$pod
# [1] "d"
#
#
# $list[[4]]$dt_txt
# [1] "2022-08-25 06:00:00"
#
#
# $list[[5]]
# $list[[5]]$dt
# [1] 1661418000
#
# $list[[5]]$main
# $list[[5]]$main$temp
# [1] 22.65
#
# $list[[5]]$main$feels_like
# [1] 22.82
#
# $list[[5]]$main$temp_min
# [1] 22.65
#
# $list[[5]]$main$temp_max
# [1] 22.65
#
# $list[[5]]$main$pressure
# [1] 1008
#
# $list[[5]]$main$sea_level
# [1] 1008
#
# $list[[5]]$main$grnd_level
# [1] 1002
#
# $list[[5]]$main$humidity
# [1] 71
#
# $list[[5]]$main$temp_kf
# [1] 0
#
#
# $list[[5]]$weather
# $list[[5]]$weather[[1]]
# $list[[5]]$weather[[1]]$id
# [1] 804
#
# $list[[5]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[5]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[5]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[5]]$clouds
# $list[[5]]$clouds$all
# [1] 99
#
#
# $list[[5]]$wind
# $list[[5]]$wind$speed
# [1] 2.65
#
# $list[[5]]$wind$deg
# [1] 251
#
# $list[[5]]$wind$gust
# [1] 5.12
#
#
# $list[[5]]$visibility
# [1] 10000
#
# $list[[5]]$pop
# [1] 0.16
#
# $list[[5]]$sys
# $list[[5]]$sys$pod
# [1] "d"
#
#
# $list[[5]]$dt_txt
# [1] "2022-08-25 09:00:00"
#
#
# $list[[6]]
# $list[[6]]$dt
# [1] 1661428800
#
# $list[[6]]$main
# $list[[6]]$main$temp
# [1] 21.19
#
# $list[[6]]$main$feels_like
# [1] 21.53
#
# $list[[6]]$main$temp_min
# [1] 21.19
#
# $list[[6]]$main$temp_max
# [1] 21.19
#
# $list[[6]]$main$pressure
# [1] 1009
#
# $list[[6]]$main$sea_level
# [1] 1009
#
# $list[[6]]$main$grnd_level
# [1] 1002
#
# $list[[6]]$main$humidity
# [1] 83
#
# $list[[6]]$main$temp_kf
# [1] 0
#
#
# $list[[6]]$weather
# $list[[6]]$weather[[1]]
# $list[[6]]$weather[[1]]$id
# [1] 500
#
# $list[[6]]$weather[[1]]$main
# [1] "Rain"
#
# $list[[6]]$weather[[1]]$description
# [1] "light rain"
#
# $list[[6]]$weather[[1]]$icon
# [1] "10n"
#
#
#
# $list[[6]]$clouds
# $list[[6]]$clouds$all
# [1] 99
#
#
# $list[[6]]$wind
# $list[[6]]$wind$speed
# [1] 2.33
#
# $list[[6]]$wind$deg
# [1] 269
#
# $list[[6]]$wind$gust
# [1] 6.81
#
#
# $list[[6]]$visibility
# [1] 10000
#
# $list[[6]]$pop
# [1] 0.2
#
# $list[[6]]$rain
# $list[[6]]$rain$`3h`
# [1] 0.32
#
#
# $list[[6]]$sys
# $list[[6]]$sys$pod
# [1] "n"
#
#
# $list[[6]]$dt_txt
# [1] "2022-08-25 12:00:00"
#
#
# $list[[7]]
# $list[[7]]$dt
# [1] 1661439600
#
# $list[[7]]$main
# $list[[7]]$main$temp
# [1] 20.38
#
# $list[[7]]$main$feels_like
# [1] 20.75
#
# $list[[7]]$main$temp_min
# [1] 20.38
#
# $list[[7]]$main$temp_max
# [1] 20.38
#
# $list[[7]]$main$pressure
# [1] 1008
#
# $list[[7]]$main$sea_level
# [1] 1008
#
# $list[[7]]$main$grnd_level
# [1] 1001
#
# $list[[7]]$main$humidity
# [1] 87
#
# $list[[7]]$main$temp_kf
# [1] 0
#
#
# $list[[7]]$weather
# $list[[7]]$weather[[1]]
# $list[[7]]$weather[[1]]$id
# [1] 500
#
# $list[[7]]$weather[[1]]$main
# [1] "Rain"
#
# $list[[7]]$weather[[1]]$description
# [1] "light rain"
#
# $list[[7]]$weather[[1]]$icon
# [1] "10n"
#
#
#
# $list[[7]]$clouds
# $list[[7]]$clouds$all
# [1] 99
#
#
# $list[[7]]$wind
# $list[[7]]$wind$speed
# [1] 0.94
#
# $list[[7]]$wind$deg
# [1] 294
#
# $list[[7]]$wind$gust
# [1] 1.76
#
#
# $list[[7]]$visibility
# [1] 10000
#
# $list[[7]]$pop
# [1] 0.32
#
# $list[[7]]$rain
# $list[[7]]$rain$`3h`
# [1] 0.29
#
#
# $list[[7]]$sys
# $list[[7]]$sys$pod
# [1] "n"
#
#
# $list[[7]]$dt_txt
# [1] "2022-08-25 15:00:00"
#
#
# $list[[8]]
# $list[[8]]$dt
# [1] 1661450400
#
# $list[[8]]$main
# $list[[8]]$main$temp
# [1] 19.57
#
# $list[[8]]$main$feels_like
# [1] 19.93
#
# $list[[8]]$main$temp_min
# [1] 19.57
#
# $list[[8]]$main$temp_max
# [1] 19.57
#
# $list[[8]]$main$pressure
# [1] 1007
#
# $list[[8]]$main$sea_level
# [1] 1007
#
# $list[[8]]$main$grnd_level
# [1] 1001
#
# $list[[8]]$main$humidity
# [1] 90
#
# $list[[8]]$main$temp_kf
# [1] 0
#
#
# $list[[8]]$weather
# $list[[8]]$weather[[1]]
# $list[[8]]$weather[[1]]$id
# [1] 803
#
# $list[[8]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[8]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[8]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[8]]$clouds
# $list[[8]]$clouds$all
# [1] 54
#
#
# $list[[8]]$wind
# $list[[8]]$wind$speed
# [1] 0.43
#
# $list[[8]]$wind$deg
# [1] 124
#
# $list[[8]]$wind$gust
# [1] 0.51
#
#
# $list[[8]]$visibility
# [1] 10000
#
# $list[[8]]$pop
# [1] 0
#
# $list[[8]]$sys
# $list[[8]]$sys$pod
# [1] "n"
#
#
# $list[[8]]$dt_txt
# [1] "2022-08-25 18:00:00"
#
#
# $list[[9]]
# $list[[9]]$dt
# [1] 1661461200
#
# $list[[9]]$main
# $list[[9]]$main$temp
# [1] 19.79
#
# $list[[9]]$main$feels_like
# [1] 20.17
#
# $list[[9]]$main$temp_min
# [1] 19.79
#
# $list[[9]]$main$temp_max
# [1] 19.79
#
# $list[[9]]$main$pressure
# [1] 1007
#
# $list[[9]]$main$sea_level
# [1] 1007
#
# $list[[9]]$main$grnd_level
# [1] 1001
#
# $list[[9]]$main$humidity
# [1] 90
#
# $list[[9]]$main$temp_kf
# [1] 0
#
#
# $list[[9]]$weather
# $list[[9]]$weather[[1]]
# $list[[9]]$weather[[1]]$id
# [1] 803
#
# $list[[9]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[9]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[9]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[9]]$clouds
# $list[[9]]$clouds$all
# [1] 53
#
#
# $list[[9]]$wind
# $list[[9]]$wind$speed
# [1] 1.13
#
# $list[[9]]$wind$deg
# [1] 140
#
# $list[[9]]$wind$gust
# [1] 1.57
#
#
# $list[[9]]$visibility
# [1] 10000
#
# $list[[9]]$pop
# [1] 0.21
#
# $list[[9]]$sys
# $list[[9]]$sys$pod
# [1] "d"
#
#
# $list[[9]]$dt_txt
# [1] "2022-08-25 21:00:00"
#
#
# $list[[10]]
# $list[[10]]$dt
# [1] 1661472000
#
# $list[[10]]$main
# $list[[10]]$main$temp
# [1] 22.24
#
# $list[[10]]$main$feels_like
# [1] 22.63
#
# $list[[10]]$main$temp_min
# [1] 22.24
#
# $list[[10]]$main$temp_max
# [1] 22.24
#
# $list[[10]]$main$pressure
# [1] 1008
#
# $list[[10]]$main$sea_level
# [1] 1008
#
# $list[[10]]$main$grnd_level
# [1] 1001
#
# $list[[10]]$main$humidity
# [1] 81
#
# $list[[10]]$main$temp_kf
# [1] 0
#
#
# $list[[10]]$weather
# $list[[10]]$weather[[1]]
# $list[[10]]$weather[[1]]$id
# [1] 803
#
# $list[[10]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[10]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[10]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[10]]$clouds
# $list[[10]]$clouds$all
# [1] 74
#
#
# $list[[10]]$wind
# $list[[10]]$wind$speed
# [1] 0.86
#
# $list[[10]]$wind$deg
# [1] 116
#
# $list[[10]]$wind$gust
# [1] 1.08
#
#
# $list[[10]]$visibility
# [1] 10000
#
# $list[[10]]$pop
# [1] 0.17
#
# $list[[10]]$sys
# $list[[10]]$sys$pod
# [1] "d"
#
#
# $list[[10]]$dt_txt
# [1] "2022-08-26 00:00:00"
#
#
# $list[[11]]
# $list[[11]]$dt
# [1] 1661482800
#
# $list[[11]]$main
# $list[[11]]$main$temp
# [1] 27.67
#
# $list[[11]]$main$feels_like
# [1] 28.17
#
# $list[[11]]$main$temp_min
# [1] 27.67
#
# $list[[11]]$main$temp_max
# [1] 27.67
#
# $list[[11]]$main$pressure
# [1] 1006
#
# $list[[11]]$main$sea_level
# [1] 1006
#
# $list[[11]]$main$grnd_level
# [1] 1000
#
# $list[[11]]$main$humidity
# [1] 51
#
# $list[[11]]$main$temp_kf
# [1] 0
#
#
# $list[[11]]$weather
# $list[[11]]$weather[[1]]
# $list[[11]]$weather[[1]]$id
# [1] 803
#
# $list[[11]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[11]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[11]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[11]]$clouds
# $list[[11]]$clouds$all
# [1] 66
#
#
# $list[[11]]$wind
# $list[[11]]$wind$speed
# [1] 1.06
#
# $list[[11]]$wind$deg
# [1] 233
#
# $list[[11]]$wind$gust
# [1] 1.75
#
#
# $list[[11]]$visibility
# [1] 10000
#
# $list[[11]]$pop
# [1] 0
#
# $list[[11]]$sys
# $list[[11]]$sys$pod
# [1] "d"
#
#
# $list[[11]]$dt_txt
# [1] "2022-08-26 03:00:00"
#
#
# $list[[12]]
# $list[[12]]$dt
# [1] 1661493600
#
# $list[[12]]$main
# $list[[12]]$main$temp
# [1] 29.76
#
# $list[[12]]$main$feels_like
# [1] 28.76
#
# $list[[12]]$main$temp_min
# [1] 29.76
#
# $list[[12]]$main$temp_max
# [1] 29.76
#
# $list[[12]]$main$pressure
# [1] 1005
#
# $list[[12]]$main$sea_level
# [1] 1005
#
# $list[[12]]$main$grnd_level
# [1] 999
#
# $list[[12]]$main$humidity
# [1] 33
#
# $list[[12]]$main$temp_kf
# [1] 0
#
#
# $list[[12]]$weather
# $list[[12]]$weather[[1]]
# $list[[12]]$weather[[1]]$id
# [1] 803
#
# $list[[12]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[12]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[12]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[12]]$clouds
# $list[[12]]$clouds$all
# [1] 68
#
#
# $list[[12]]$wind
# $list[[12]]$wind$speed
# [1] 2.51
#
# $list[[12]]$wind$deg
# [1] 283
#
# $list[[12]]$wind$gust
# [1] 3.4
#
#
# $list[[12]]$visibility
# [1] 10000
#
# $list[[12]]$pop
# [1] 0
#
# $list[[12]]$sys
# $list[[12]]$sys$pod
# [1] "d"
#
#
# $list[[12]]$dt_txt
# [1] "2022-08-26 06:00:00"
#
#
# $list[[13]]
# $list[[13]]$dt
# [1] 1661504400
#
# $list[[13]]$main
# $list[[13]]$main$temp
# [1] 26.73
#
# $list[[13]]$main$feels_like
# [1] 26.91
#
# $list[[13]]$main$temp_min
# [1] 26.73
#
# $list[[13]]$main$temp_max
# [1] 26.73
#
# $list[[13]]$main$pressure
# [1] 1006
#
# $list[[13]]$main$sea_level
# [1] 1006
#
# $list[[13]]$main$grnd_level
# [1] 999
#
# $list[[13]]$main$humidity
# [1] 45
#
# $list[[13]]$main$temp_kf
# [1] 0
#
#
# $list[[13]]$weather
# $list[[13]]$weather[[1]]
# $list[[13]]$weather[[1]]$id
# [1] 804
#
# $list[[13]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[13]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[13]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[13]]$clouds
# $list[[13]]$clouds$all
# [1] 100
#
#
# $list[[13]]$wind
# $list[[13]]$wind$speed
# [1] 2.53
#
# $list[[13]]$wind$deg
# [1] 286
#
# $list[[13]]$wind$gust
# [1] 4.07
#
#
# $list[[13]]$visibility
# [1] 10000
#
# $list[[13]]$pop
# [1] 0
#
# $list[[13]]$sys
# $list[[13]]$sys$pod
# [1] "d"
#
#
# $list[[13]]$dt_txt
# [1] "2022-08-26 09:00:00"
#
#
# $list[[14]]
# $list[[14]]$dt
# [1] 1661515200
#
# $list[[14]]$main
# $list[[14]]$main$temp
# [1] 23.56
#
# $list[[14]]$main$feels_like
# [1] 23.72
#
# $list[[14]]$main$temp_min
# [1] 23.56
#
# $list[[14]]$main$temp_max
# [1] 23.56
#
# $list[[14]]$main$pressure
# [1] 1008
#
# $list[[14]]$main$sea_level
# [1] 1008
#
# $list[[14]]$main$grnd_level
# [1] 1001
#
# $list[[14]]$main$humidity
# [1] 67
#
# $list[[14]]$main$temp_kf
# [1] 0
#
#
# $list[[14]]$weather
# $list[[14]]$weather[[1]]
# $list[[14]]$weather[[1]]$id
# [1] 804
#
# $list[[14]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[14]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[14]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[14]]$clouds
# $list[[14]]$clouds$all
# [1] 94
#
#
# $list[[14]]$wind
# $list[[14]]$wind$speed
# [1] 2.6
#
# $list[[14]]$wind$deg
# [1] 281
#
# $list[[14]]$wind$gust
# [1] 6.27
#
#
# $list[[14]]$visibility
# [1] 10000
#
# $list[[14]]$pop
# [1] 0
#
# $list[[14]]$sys
# $list[[14]]$sys$pod
# [1] "n"
#
#
# $list[[14]]$dt_txt
# [1] "2022-08-26 12:00:00"
#
#
# $list[[15]]
# $list[[15]]$dt
# [1] 1661526000
#
# $list[[15]]$main
# $list[[15]]$main$temp
# [1] 22.41
#
# $list[[15]]$main$feels_like
# [1] 22.43
#
# $list[[15]]$main$temp_min
# [1] 22.41
#
# $list[[15]]$main$temp_max
# [1] 22.41
#
# $list[[15]]$main$pressure
# [1] 1008
#
# $list[[15]]$main$sea_level
# [1] 1008
#
# $list[[15]]$main$grnd_level
# [1] 1001
#
# $list[[15]]$main$humidity
# [1] 66
#
# $list[[15]]$main$temp_kf
# [1] 0
#
#
# $list[[15]]$weather
# $list[[15]]$weather[[1]]
# $list[[15]]$weather[[1]]$id
# [1] 804
#
# $list[[15]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[15]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[15]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[15]]$clouds
# $list[[15]]$clouds$all
# [1] 91
#
#
# $list[[15]]$wind
# $list[[15]]$wind$speed
# [1] 1.98
#
# $list[[15]]$wind$deg
# [1] 285
#
# $list[[15]]$wind$gust
# [1] 5.78
#
#
# $list[[15]]$visibility
# [1] 10000
#
# $list[[15]]$pop
# [1] 0
#
# $list[[15]]$sys
# $list[[15]]$sys$pod
# [1] "n"
#
#
# $list[[15]]$dt_txt
# [1] "2022-08-26 15:00:00"
#
#
# $list[[16]]
# $list[[16]]$dt
# [1] 1661536800
#
# $list[[16]]$main
# $list[[16]]$main$temp
# [1] 20.82
#
# $list[[16]]$main$feels_like
# [1] 20.76
#
# $list[[16]]$main$temp_min
# [1] 20.82
#
# $list[[16]]$main$temp_max
# [1] 20.82
#
# $list[[16]]$main$pressure
# [1] 1008
#
# $list[[16]]$main$sea_level
# [1] 1008
#
# $list[[16]]$main$grnd_level
# [1] 1001
#
# $list[[16]]$main$humidity
# [1] 69
#
# $list[[16]]$main$temp_kf
# [1] 0
#
#
# $list[[16]]$weather
# $list[[16]]$weather[[1]]
# $list[[16]]$weather[[1]]$id
# [1] 804
#
# $list[[16]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[16]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[16]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[16]]$clouds
# $list[[16]]$clouds$all
# [1] 89
#
#
# $list[[16]]$wind
# $list[[16]]$wind$speed
# [1] 2.36
#
# $list[[16]]$wind$deg
# [1] 295
#
# $list[[16]]$wind$gust
# [1] 6.47
#
#
# $list[[16]]$visibility
# [1] 10000
#
# $list[[16]]$pop
# [1] 0
#
# $list[[16]]$sys
# $list[[16]]$sys$pod
# [1] "n"
#
#
# $list[[16]]$dt_txt
# [1] "2022-08-26 18:00:00"
#
#
# $list[[17]]
# $list[[17]]$dt
# [1] 1661547600
#
# $list[[17]]$main
# $list[[17]]$main$temp
# [1] 18.46
#
# $list[[17]]$main$feels_like
# [1] 17.88
#
# $list[[17]]$main$temp_min
# [1] 18.46
#
# $list[[17]]$main$temp_max
# [1] 18.46
#
# $list[[17]]$main$pressure
# [1] 1009
#
# $list[[17]]$main$sea_level
# [1] 1009
#
# $list[[17]]$main$grnd_level
# [1] 1002
#
# $list[[17]]$main$humidity
# [1] 58
#
# $list[[17]]$main$temp_kf
# [1] 0
#
#
# $list[[17]]$weather
# $list[[17]]$weather[[1]]
# $list[[17]]$weather[[1]]$id
# [1] 804
#
# $list[[17]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[17]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[17]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[17]]$clouds
# $list[[17]]$clouds$all
# [1] 93
#
#
# $list[[17]]$wind
# $list[[17]]$wind$speed
# [1] 3.72
#
# $list[[17]]$wind$deg
# [1] 304
#
# $list[[17]]$wind$gust
# [1] 7.84
#
#
# $list[[17]]$visibility
# [1] 10000
#
# $list[[17]]$pop
# [1] 0
#
# $list[[17]]$sys
# $list[[17]]$sys$pod
# [1] "d"
#
#
# $list[[17]]$dt_txt
# [1] "2022-08-26 21:00:00"
#
#
# $list[[18]]
# $list[[18]]$dt
# [1] 1661558400
#
# $list[[18]]$main
# $list[[18]]$main$temp
# [1] 19.38
#
# $list[[18]]$main$feels_like
# [1] 18.57
#
# $list[[18]]$main$temp_min
# [1] 19.38
#
# $list[[18]]$main$temp_max
# [1] 19.38
#
# $list[[18]]$main$pressure
# [1] 1010
#
# $list[[18]]$main$sea_level
# [1] 1010
#
# $list[[18]]$main$grnd_level
# [1] 1003
#
# $list[[18]]$main$humidity
# [1] 46
#
# $list[[18]]$main$temp_kf
# [1] 0
#
#
# $list[[18]]$weather
# $list[[18]]$weather[[1]]
# $list[[18]]$weather[[1]]$id
# [1] 804
#
# $list[[18]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[18]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[18]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[18]]$clouds
# $list[[18]]$clouds$all
# [1] 91
#
#
# $list[[18]]$wind
# $list[[18]]$wind$speed
# [1] 2.78
#
# $list[[18]]$wind$deg
# [1] 304
#
# $list[[18]]$wind$gust
# [1] 4.9
#
#
# $list[[18]]$visibility
# [1] 10000
#
# $list[[18]]$pop
# [1] 0
#
# $list[[18]]$sys
# $list[[18]]$sys$pod
# [1] "d"
#
#
# $list[[18]]$dt_txt
# [1] "2022-08-27 00:00:00"
#
#
# $list[[19]]
# $list[[19]]$dt
# [1] 1661569200
#
# $list[[19]]$main
# $list[[19]]$main$temp
# [1] 24.03
#
# $list[[19]]$main$feels_like
# [1] 23.35
#
# $list[[19]]$main$temp_min
# [1] 24.03
#
# $list[[19]]$main$temp_max
# [1] 24.03
#
# $list[[19]]$main$pressure
# [1] 1009
#
# $list[[19]]$main$sea_level
# [1] 1009
#
# $list[[19]]$main$grnd_level
# [1] 1003
#
# $list[[19]]$main$humidity
# [1] 33
#
# $list[[19]]$main$temp_kf
# [1] 0
#
#
# $list[[19]]$weather
# $list[[19]]$weather[[1]]
# $list[[19]]$weather[[1]]$id
# [1] 802
#
# $list[[19]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[19]]$weather[[1]]$description
# [1] "scattered clouds"
#
# $list[[19]]$weather[[1]]$icon
# [1] "03d"
#
#
#
# $list[[19]]$clouds
# $list[[19]]$clouds$all
# [1] 35
#
#
# $list[[19]]$wind
# $list[[19]]$wind$speed
# [1] 4.68
#
# $list[[19]]$wind$deg
# [1] 312
#
# $list[[19]]$wind$gust
# [1] 6.28
#
#
# $list[[19]]$visibility
# [1] 10000
#
# $list[[19]]$pop
# [1] 0
#
# $list[[19]]$sys
# $list[[19]]$sys$pod
# [1] "d"
#
#
# $list[[19]]$dt_txt
# [1] "2022-08-27 03:00:00"
#
#
# $list[[20]]
# $list[[20]]$dt
# [1] 1661580000
#
# $list[[20]]$main
# $list[[20]]$main$temp
# [1] 24.91
#
# $list[[20]]$main$feels_like
# [1] 24.32
#
# $list[[20]]$main$temp_min
# [1] 24.91
#
# $list[[20]]$main$temp_max
# [1] 24.91
#
# $list[[20]]$main$pressure
# [1] 1008
#
# $list[[20]]$main$sea_level
# [1] 1008
#
# $list[[20]]$main$grnd_level
# [1] 1002
#
# $list[[20]]$main$humidity
# [1] 33
#
# $list[[20]]$main$temp_kf
# [1] 0
#
#
# $list[[20]]$weather
# $list[[20]]$weather[[1]]
# $list[[20]]$weather[[1]]$id
# [1] 802
#
# $list[[20]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[20]]$weather[[1]]$description
# [1] "scattered clouds"
#
# $list[[20]]$weather[[1]]$icon
# [1] "03d"
#
#
#
# $list[[20]]$clouds
# $list[[20]]$clouds$all
# [1] 45
#
#
# $list[[20]]$wind
# $list[[20]]$wind$speed
# [1] 5.17
#
# $list[[20]]$wind$deg
# [1] 318
#
# $list[[20]]$wind$gust
# [1] 5.86
#
#
# $list[[20]]$visibility
# [1] 10000
#
# $list[[20]]$pop
# [1] 0
#
# $list[[20]]$sys
# $list[[20]]$sys$pod
# [1] "d"
#
#
# $list[[20]]$dt_txt
# [1] "2022-08-27 06:00:00"
#
#
# $list[[21]]
# $list[[21]]$dt
# [1] 1661590800
#
# $list[[21]]$main
# $list[[21]]$main$temp
# [1] 22.81
#
# $list[[21]]$main$feels_like
# [1] 22.27
#
# $list[[21]]$main$temp_min
# [1] 22.81
#
# $list[[21]]$main$temp_max
# [1] 22.81
#
# $list[[21]]$main$pressure
# [1] 1010
#
# $list[[21]]$main$sea_level
# [1] 1010
#
# $list[[21]]$main$grnd_level
# [1] 1003
#
# $list[[21]]$main$humidity
# [1] 43
#
# $list[[21]]$main$temp_kf
# [1] 0
#
#
# $list[[21]]$weather
# $list[[21]]$weather[[1]]
# $list[[21]]$weather[[1]]$id
# [1] 804
#
# $list[[21]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[21]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[21]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[21]]$clouds
# $list[[21]]$clouds$all
# [1] 91
#
#
# $list[[21]]$wind
# $list[[21]]$wind$speed
# [1] 4.23
#
# $list[[21]]$wind$deg
# [1] 317
#
# $list[[21]]$wind$gust
# [1] 5.16
#
#
# $list[[21]]$visibility
# [1] 10000
#
# $list[[21]]$pop
# [1] 0
#
# $list[[21]]$sys
# $list[[21]]$sys$pod
# [1] "d"
#
#
# $list[[21]]$dt_txt
# [1] "2022-08-27 09:00:00"
#
#
# $list[[22]]
# $list[[22]]$dt
# [1] 1661601600
#
# $list[[22]]$main
# $list[[22]]$main$temp
# [1] 20.1
#
# $list[[22]]$main$feels_like
# [1] 19.73
#
# $list[[22]]$main$temp_min
# [1] 20.1
#
# $list[[22]]$main$temp_max
# [1] 20.1
#
# $list[[22]]$main$pressure
# [1] 1011
#
# $list[[22]]$main$sea_level
# [1] 1011
#
# $list[[22]]$main$grnd_level
# [1] 1005
#
# $list[[22]]$main$humidity
# [1] 60
#
# $list[[22]]$main$temp_kf
# [1] 0
#
#
# $list[[22]]$weather
# $list[[22]]$weather[[1]]
# $list[[22]]$weather[[1]]$id
# [1] 803
#
# $list[[22]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[22]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[22]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[22]]$clouds
# $list[[22]]$clouds$all
# [1] 68
#
#
# $list[[22]]$wind
# $list[[22]]$wind$speed
# [1] 1.74
#
# $list[[22]]$wind$deg
# [1] 302
#
# $list[[22]]$wind$gust
# [1] 4.02
#
#
# $list[[22]]$visibility
# [1] 10000
#
# $list[[22]]$pop
# [1] 0
#
# $list[[22]]$sys
# $list[[22]]$sys$pod
# [1] "n"
#
#
# $list[[22]]$dt_txt
# [1] "2022-08-27 12:00:00"
#
#
# $list[[23]]
# $list[[23]]$dt
# [1] 1661612400
#
# $list[[23]]$main
# $list[[23]]$main$temp
# [1] 18.93
#
# $list[[23]]$main$feels_like
# [1] 18.63
#
# $list[[23]]$main$temp_min
# [1] 18.93
#
# $list[[23]]$main$temp_max
# [1] 18.93
#
# $list[[23]]$main$pressure
# [1] 1012
#
# $list[[23]]$main$sea_level
# [1] 1012
#
# $list[[23]]$main$grnd_level
# [1] 1006
#
# $list[[23]]$main$humidity
# [1] 67
#
# $list[[23]]$main$temp_kf
# [1] 0
#
#
# $list[[23]]$weather
# $list[[23]]$weather[[1]]
# $list[[23]]$weather[[1]]$id
# [1] 803
#
# $list[[23]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[23]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[23]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[23]]$clouds
# $list[[23]]$clouds$all
# [1] 67
#
#
# $list[[23]]$wind
# $list[[23]]$wind$speed
# [1] 0.31
#
# $list[[23]]$wind$deg
# [1] 46
#
# $list[[23]]$wind$gust
# [1] 0.44
#
#
# $list[[23]]$visibility
# [1] 10000
#
# $list[[23]]$pop
# [1] 0
#
# $list[[23]]$sys
# $list[[23]]$sys$pod
# [1] "n"
#
#
# $list[[23]]$dt_txt
# [1] "2022-08-27 15:00:00"
#
#
# $list[[24]]
# $list[[24]]$dt
# [1] 1661623200
#
# $list[[24]]$main
# $list[[24]]$main$temp
# [1] 17.65
#
# $list[[24]]$main$feels_like
# [1] 17.32
#
# $list[[24]]$main$temp_min
# [1] 17.65
#
# $list[[24]]$main$temp_max
# [1] 17.65
#
# $list[[24]]$main$pressure
# [1] 1013
#
# $list[[24]]$main$sea_level
# [1] 1013
#
# $list[[24]]$main$grnd_level
# [1] 1006
#
# $list[[24]]$main$humidity
# [1] 71
#
# $list[[24]]$main$temp_kf
# [1] 0
#
#
# $list[[24]]$weather
# $list[[24]]$weather[[1]]
# $list[[24]]$weather[[1]]$id
# [1] 803
#
# $list[[24]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[24]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[24]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[24]]$clouds
# $list[[24]]$clouds$all
# [1] 56
#
#
# $list[[24]]$wind
# $list[[24]]$wind$speed
# [1] 1.26
#
# $list[[24]]$wind$deg
# [1] 90
#
# $list[[24]]$wind$gust
# [1] 1.5
#
#
# $list[[24]]$visibility
# [1] 10000
#
# $list[[24]]$pop
# [1] 0
#
# $list[[24]]$sys
# $list[[24]]$sys$pod
# [1] "n"
#
#
# $list[[24]]$dt_txt
# [1] "2022-08-27 18:00:00"
#
#
# $list[[25]]
# $list[[25]]$dt
# [1] 1661634000
#
# $list[[25]]$main
# $list[[25]]$main$temp
# [1] 16.51
#
# $list[[25]]$main$feels_like
# [1] 16.12
#
# $list[[25]]$main$temp_min
# [1] 16.51
#
# $list[[25]]$main$temp_max
# [1] 16.51
#
# $list[[25]]$main$pressure
# [1] 1014
#
# $list[[25]]$main$sea_level
# [1] 1014
#
# $list[[25]]$main$grnd_level
# [1] 1007
#
# $list[[25]]$main$humidity
# [1] 73
#
# $list[[25]]$main$temp_kf
# [1] 0
#
#
# $list[[25]]$weather
# $list[[25]]$weather[[1]]
# $list[[25]]$weather[[1]]$id
# [1] 801
#
# $list[[25]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[25]]$weather[[1]]$description
# [1] "few clouds"
#
# $list[[25]]$weather[[1]]$icon
# [1] "02d"
#
#
#
# $list[[25]]$clouds
# $list[[25]]$clouds$all
# [1] 13
#
#
# $list[[25]]$wind
# $list[[25]]$wind$speed
# [1] 1.19
#
# $list[[25]]$wind$deg
# [1] 89
#
# $list[[25]]$wind$gust
# [1] 1.3
#
#
# $list[[25]]$visibility
# [1] 10000
#
# $list[[25]]$pop
# [1] 0
#
# $list[[25]]$sys
# $list[[25]]$sys$pod
# [1] "d"
#
#
# $list[[25]]$dt_txt
# [1] "2022-08-27 21:00:00"
#
#
# $list[[26]]
# $list[[26]]$dt
# [1] 1661644800
#
# $list[[26]]$main
# $list[[26]]$main$temp
# [1] 20.7
#
# $list[[26]]$main$feels_like
# [1] 20.26
#
# $list[[26]]$main$temp_min
# [1] 20.7
#
# $list[[26]]$main$temp_max
# [1] 20.7
#
# $list[[26]]$main$pressure
# [1] 1015
#
# $list[[26]]$main$sea_level
# [1] 1015
#
# $list[[26]]$main$grnd_level
# [1] 1008
#
# $list[[26]]$main$humidity
# [1] 55
#
# $list[[26]]$main$temp_kf
# [1] 0
#
#
# $list[[26]]$weather
# $list[[26]]$weather[[1]]
# $list[[26]]$weather[[1]]$id
# [1] 802
#
# $list[[26]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[26]]$weather[[1]]$description
# [1] "scattered clouds"
#
# $list[[26]]$weather[[1]]$icon
# [1] "03d"
#
#
#
# $list[[26]]$clouds
# $list[[26]]$clouds$all
# [1] 49
#
#
# $list[[26]]$wind
# $list[[26]]$wind$speed
# [1] 1.57
#
# $list[[26]]$wind$deg
# [1] 89
#
# $list[[26]]$wind$gust
# [1] 2.5
#
#
# $list[[26]]$visibility
# [1] 10000
#
# $list[[26]]$pop
# [1] 0
#
# $list[[26]]$sys
# $list[[26]]$sys$pod
# [1] "d"
#
#
# $list[[26]]$dt_txt
# [1] "2022-08-28 00:00:00"
#
#
# $list[[27]]
# $list[[27]]$dt
# [1] 1661655600
#
# $list[[27]]$main
# $list[[27]]$main$temp
# [1] 26.12
#
# $list[[27]]$main$feels_like
# [1] 26.12
#
# $list[[27]]$main$temp_min
# [1] 26.12
#
# $list[[27]]$main$temp_max
# [1] 26.12
#
# $list[[27]]$main$pressure
# [1] 1014
#
# $list[[27]]$main$sea_level
# [1] 1014
#
# $list[[27]]$main$grnd_level
# [1] 1008
#
# $list[[27]]$main$humidity
# [1] 36
#
# $list[[27]]$main$temp_kf
# [1] 0
#
#
# $list[[27]]$weather
# $list[[27]]$weather[[1]]
# $list[[27]]$weather[[1]]$id
# [1] 803
#
# $list[[27]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[27]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[27]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[27]]$clouds
# $list[[27]]$clouds$all
# [1] 66
#
#
# $list[[27]]$wind
# $list[[27]]$wind$speed
# [1] 1.98
#
# $list[[27]]$wind$deg
# [1] 139
#
# $list[[27]]$wind$gust
# [1] 2.93
#
#
# $list[[27]]$visibility
# [1] 10000
#
# $list[[27]]$pop
# [1] 0
#
# $list[[27]]$sys
# $list[[27]]$sys$pod
# [1] "d"
#
#
# $list[[27]]$dt_txt
# [1] "2022-08-28 03:00:00"
#
#
# $list[[28]]
# $list[[28]]$dt
# [1] 1661666400
#
# $list[[28]]$main
# $list[[28]]$main$temp
# [1] 27.76
#
# $list[[28]]$main$feels_like
# [1] 27.06
#
# $list[[28]]$main$temp_min
# [1] 27.76
#
# $list[[28]]$main$temp_max
# [1] 27.76
#
# $list[[28]]$main$pressure
# [1] 1013
#
# $list[[28]]$main$sea_level
# [1] 1013
#
# $list[[28]]$main$grnd_level
# [1] 1007
#
# $list[[28]]$main$humidity
# [1] 33
#
# $list[[28]]$main$temp_kf
# [1] 0
#
#
# $list[[28]]$weather
# $list[[28]]$weather[[1]]
# $list[[28]]$weather[[1]]$id
# [1] 803
#
# $list[[28]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[28]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[28]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[28]]$clouds
# $list[[28]]$clouds$all
# [1] 58
#
#
# $list[[28]]$wind
# $list[[28]]$wind$speed
# [1] 2.64
#
# $list[[28]]$wind$deg
# [1] 158
#
# $list[[28]]$wind$gust
# [1] 2.92
#
#
# $list[[28]]$visibility
# [1] 10000
#
# $list[[28]]$pop
# [1] 0
#
# $list[[28]]$sys
# $list[[28]]$sys$pod
# [1] "d"
#
#
# $list[[28]]$dt_txt
# [1] "2022-08-28 06:00:00"
#
#
# $list[[29]]
# $list[[29]]$dt
# [1] 1661677200
#
# $list[[29]]$main
# $list[[29]]$main$temp
# [1] 26.05
#
# $list[[29]]$main$feels_like
# [1] 26.05
#
# $list[[29]]$main$temp_min
# [1] 26.05
#
# $list[[29]]$main$temp_max
# [1] 26.05
#
# $list[[29]]$main$pressure
# [1] 1014
#
# $list[[29]]$main$sea_level
# [1] 1014
#
# $list[[29]]$main$grnd_level
# [1] 1007
#
# $list[[29]]$main$humidity
# [1] 42
#
# $list[[29]]$main$temp_kf
# [1] 0
#
#
# $list[[29]]$weather
# $list[[29]]$weather[[1]]
# $list[[29]]$weather[[1]]$id
# [1] 803
#
# $list[[29]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[29]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[29]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[29]]$clouds
# $list[[29]]$clouds$all
# [1] 64
#
#
# $list[[29]]$wind
# $list[[29]]$wind$speed
# [1] 1.04
#
# $list[[29]]$wind$deg
# [1] 184
#
# $list[[29]]$wind$gust
# [1] 2.11
#
#
# $list[[29]]$visibility
# [1] 10000
#
# $list[[29]]$pop
# [1] 0
#
# $list[[29]]$sys
# $list[[29]]$sys$pod
# [1] "d"
#
#
# $list[[29]]$dt_txt
# [1] "2022-08-28 09:00:00"
#
#
# $list[[30]]
# $list[[30]]$dt
# [1] 1661688000
#
# $list[[30]]$main
# $list[[30]]$main$temp
# [1] 23.26
#
# $list[[30]]$main$feels_like
# [1] 23.03
#
# $list[[30]]$main$temp_min
# [1] 23.26
#
# $list[[30]]$main$temp_max
# [1] 23.26
#
# $list[[30]]$main$pressure
# [1] 1015
#
# $list[[30]]$main$sea_level
# [1] 1015
#
# $list[[30]]$main$grnd_level
# [1] 1008
#
# $list[[30]]$main$humidity
# [1] 53
#
# $list[[30]]$main$temp_kf
# [1] 0
#
#
# $list[[30]]$weather
# $list[[30]]$weather[[1]]
# $list[[30]]$weather[[1]]$id
# [1] 803
#
# $list[[30]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[30]]$weather[[1]]$description
# [1] "broken clouds"
#
# $list[[30]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[30]]$clouds
# $list[[30]]$clouds$all
# [1] 80
#
#
# $list[[30]]$wind
# $list[[30]]$wind$speed
# [1] 0.79
#
# $list[[30]]$wind$deg
# [1] 329
#
# $list[[30]]$wind$gust
# [1] 1.21
#
#
# $list[[30]]$visibility
# [1] 10000
#
# $list[[30]]$pop
# [1] 0
#
# $list[[30]]$sys
# $list[[30]]$sys$pod
# [1] "n"
#
#
# $list[[30]]$dt_txt
# [1] "2022-08-28 12:00:00"
#
#
# $list[[31]]
# $list[[31]]$dt
# [1] 1661698800
#
# $list[[31]]$main
# $list[[31]]$main$temp
# [1] 22.43
#
# $list[[31]]$main$feels_like
# [1] 22.24
#
# $list[[31]]$main$temp_min
# [1] 22.43
#
# $list[[31]]$main$temp_max
# [1] 22.43
#
# $list[[31]]$main$pressure
# [1] 1015
#
# $list[[31]]$main$sea_level
# [1] 1015
#
# $list[[31]]$main$grnd_level
# [1] 1009
#
# $list[[31]]$main$humidity
# [1] 58
#
# $list[[31]]$main$temp_kf
# [1] 0
#
#
# $list[[31]]$weather
# $list[[31]]$weather[[1]]
# $list[[31]]$weather[[1]]$id
# [1] 804
#
# $list[[31]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[31]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[31]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[31]]$clouds
# $list[[31]]$clouds$all
# [1] 100
#
#
# $list[[31]]$wind
# $list[[31]]$wind$speed
# [1] 0.79
#
# $list[[31]]$wind$deg
# [1] 119
#
# $list[[31]]$wind$gust
# [1] 1.08
#
#
# $list[[31]]$visibility
# [1] 10000
#
# $list[[31]]$pop
# [1] 0
#
# $list[[31]]$sys
# $list[[31]]$sys$pod
# [1] "n"
#
#
# $list[[31]]$dt_txt
# [1] "2022-08-28 15:00:00"
#
#
# $list[[32]]
# $list[[32]]$dt
# [1] 1661709600
#
# $list[[32]]$main
# $list[[32]]$main$temp
# [1] 21.24
#
# $list[[32]]$main$feels_like
# [1] 21.12
#
# $list[[32]]$main$temp_min
# [1] 21.24
#
# $list[[32]]$main$temp_max
# [1] 21.24
#
# $list[[32]]$main$pressure
# [1] 1016
#
# $list[[32]]$main$sea_level
# [1] 1016
#
# $list[[32]]$main$grnd_level
# [1] 1009
#
# $list[[32]]$main$humidity
# [1] 65
#
# $list[[32]]$main$temp_kf
# [1] 0
#
#
# $list[[32]]$weather
# $list[[32]]$weather[[1]]
# $list[[32]]$weather[[1]]$id
# [1] 804
#
# $list[[32]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[32]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[32]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[32]]$clouds
# $list[[32]]$clouds$all
# [1] 100
#
#
# $list[[32]]$wind
# $list[[32]]$wind$speed
# [1] 1.14
#
# $list[[32]]$wind$deg
# [1] 137
#
# $list[[32]]$wind$gust
# [1] 1.79
#
#
# $list[[32]]$visibility
# [1] 10000
#
# $list[[32]]$pop
# [1] 0
#
# $list[[32]]$sys
# $list[[32]]$sys$pod
# [1] "n"
#
#
# $list[[32]]$dt_txt
# [1] "2022-08-28 18:00:00"
#
#
# $list[[33]]
# $list[[33]]$dt
# [1] 1661720400
#
# $list[[33]]$main
# $list[[33]]$main$temp
# [1] 20.58
#
# $list[[33]]$main$feels_like
# [1] 20.42
#
# $list[[33]]$main$temp_min
# [1] 20.58
#
# $list[[33]]$main$temp_max
# [1] 20.58
#
# $list[[33]]$main$pressure
# [1] 1016
#
# $list[[33]]$main$sea_level
# [1] 1016
#
# $list[[33]]$main$grnd_level
# [1] 1009
#
# $list[[33]]$main$humidity
# [1] 66
#
# $list[[33]]$main$temp_kf
# [1] 0
#
#
# $list[[33]]$weather
# $list[[33]]$weather[[1]]
# $list[[33]]$weather[[1]]$id
# [1] 804
#
# $list[[33]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[33]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[33]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[33]]$clouds
# $list[[33]]$clouds$all
# [1] 97
#
#
# $list[[33]]$wind
# $list[[33]]$wind$speed
# [1] 1.09
#
# $list[[33]]$wind$deg
# [1] 96
#
# $list[[33]]$wind$gust
# [1] 1.75
#
#
# $list[[33]]$visibility
# [1] 10000
#
# $list[[33]]$pop
# [1] 0
#
# $list[[33]]$sys
# $list[[33]]$sys$pod
# [1] "d"
#
#
# $list[[33]]$dt_txt
# [1] "2022-08-28 21:00:00"
#
#
# $list[[34]]
# $list[[34]]$dt
# [1] 1661731200
#
# $list[[34]]$main
# $list[[34]]$main$temp
# [1] 21.68
#
# $list[[34]]$main$feels_like
# [1] 21.42
#
# $list[[34]]$main$temp_min
# [1] 21.68
#
# $list[[34]]$main$temp_max
# [1] 21.68
#
# $list[[34]]$main$pressure
# [1] 1017
#
# $list[[34]]$main$sea_level
# [1] 1017
#
# $list[[34]]$main$grnd_level
# [1] 1010
#
# $list[[34]]$main$humidity
# [1] 58
#
# $list[[34]]$main$temp_kf
# [1] 0
#
#
# $list[[34]]$weather
# $list[[34]]$weather[[1]]
# $list[[34]]$weather[[1]]$id
# [1] 804
#
# $list[[34]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[34]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[34]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[34]]$clouds
# $list[[34]]$clouds$all
# [1] 98
#
#
# $list[[34]]$wind
# $list[[34]]$wind$speed
# [1] 1.34
#
# $list[[34]]$wind$deg
# [1] 100
#
# $list[[34]]$wind$gust
# [1] 2.45
#
#
# $list[[34]]$visibility
# [1] 10000
#
# $list[[34]]$pop
# [1] 0
#
# $list[[34]]$sys
# $list[[34]]$sys$pod
# [1] "d"
#
#
# $list[[34]]$dt_txt
# [1] "2022-08-29 00:00:00"
#
#
# $list[[35]]
# $list[[35]]$dt
# [1] 1661742000
#
# $list[[35]]$main
# $list[[35]]$main$temp
# [1] 23.98
#
# $list[[35]]$main$feels_like
# [1] 23.71
#
# $list[[35]]$main$temp_min
# [1] 23.98
#
# $list[[35]]$main$temp_max
# [1] 23.98
#
# $list[[35]]$main$pressure
# [1] 1016
#
# $list[[35]]$main$sea_level
# [1] 1016
#
# $list[[35]]$main$grnd_level
# [1] 1010
#
# $list[[35]]$main$humidity
# [1] 49
#
# $list[[35]]$main$temp_kf
# [1] 0
#
#
# $list[[35]]$weather
# $list[[35]]$weather[[1]]
# $list[[35]]$weather[[1]]$id
# [1] 804
#
# $list[[35]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[35]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[35]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[35]]$clouds
# $list[[35]]$clouds$all
# [1] 92
#
#
# $list[[35]]$wind
# $list[[35]]$wind$speed
# [1] 1.55
#
# $list[[35]]$wind$deg
# [1] 141
#
# $list[[35]]$wind$gust
# [1] 2.28
#
#
# $list[[35]]$visibility
# [1] 10000
#
# $list[[35]]$pop
# [1] 0
#
# $list[[35]]$sys
# $list[[35]]$sys$pod
# [1] "d"
#
#
# $list[[35]]$dt_txt
# [1] "2022-08-29 03:00:00"
#
#
# $list[[36]]
# $list[[36]]$dt
# [1] 1661752800
#
# $list[[36]]$main
# $list[[36]]$main$temp
# [1] 25.22
#
# $list[[36]]$main$feels_like
# [1] 24.89
#
# $list[[36]]$main$temp_min
# [1] 25.22
#
# $list[[36]]$main$temp_max
# [1] 25.22
#
# $list[[36]]$main$pressure
# [1] 1016
#
# $list[[36]]$main$sea_level
# [1] 1016
#
# $list[[36]]$main$grnd_level
# [1] 1009
#
# $list[[36]]$main$humidity
# [1] 42
#
# $list[[36]]$main$temp_kf
# [1] 0
#
#
# $list[[36]]$weather
# $list[[36]]$weather[[1]]
# $list[[36]]$weather[[1]]$id
# [1] 804
#
# $list[[36]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[36]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[36]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[36]]$clouds
# $list[[36]]$clouds$all
# [1] 94
#
#
# $list[[36]]$wind
# $list[[36]]$wind$speed
# [1] 1.97
#
# $list[[36]]$wind$deg
# [1] 136
#
# $list[[36]]$wind$gust
# [1] 2.56
#
#
# $list[[36]]$visibility
# [1] 10000
#
# $list[[36]]$pop
# [1] 0
#
# $list[[36]]$sys
# $list[[36]]$sys$pod
# [1] "d"
#
#
# $list[[36]]$dt_txt
# [1] "2022-08-29 06:00:00"
#
#
# $list[[37]]
# $list[[37]]$dt
# [1] 1661763600
#
# $list[[37]]$main
# $list[[37]]$main$temp
# [1] 23.45
#
# $list[[37]]$main$feels_like
# [1] 23.16
#
# $list[[37]]$main$temp_min
# [1] 23.45
#
# $list[[37]]$main$temp_max
# [1] 23.45
#
# $list[[37]]$main$pressure
# [1] 1016
#
# $list[[37]]$main$sea_level
# [1] 1016
#
# $list[[37]]$main$grnd_level
# [1] 1010
#
# $list[[37]]$main$humidity
# [1] 50
#
# $list[[37]]$main$temp_kf
# [1] 0
#
#
# $list[[37]]$weather
# $list[[37]]$weather[[1]]
# $list[[37]]$weather[[1]]$id
# [1] 804
#
# $list[[37]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[37]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[37]]$weather[[1]]$icon
# [1] "04d"
#
#
#
# $list[[37]]$clouds
# $list[[37]]$clouds$all
# [1] 95
#
#
# $list[[37]]$wind
# $list[[37]]$wind$speed
# [1] 1.36
#
# $list[[37]]$wind$deg
# [1] 167
#
# $list[[37]]$wind$gust
# [1] 2.57
#
#
# $list[[37]]$visibility
# [1] 10000
#
# $list[[37]]$pop
# [1] 0
#
# $list[[37]]$sys
# $list[[37]]$sys$pod
# [1] "d"
#
#
# $list[[37]]$dt_txt
# [1] "2022-08-29 09:00:00"
#
#
# $list[[38]]
# $list[[38]]$dt
# [1] 1661774400
#
# $list[[38]]$main
# $list[[38]]$main$temp
# [1] 22.45
#
# $list[[38]]$main$feels_like
# [1] 22.24
#
# $list[[38]]$main$temp_min
# [1] 22.45
#
# $list[[38]]$main$temp_max
# [1] 22.45
#
# $list[[38]]$main$pressure
# [1] 1017
#
# $list[[38]]$main$sea_level
# [1] 1017
#
# $list[[38]]$main$grnd_level
# [1] 1011
#
# $list[[38]]$main$humidity
# [1] 57
#
# $list[[38]]$main$temp_kf
# [1] 0
#
#
# $list[[38]]$weather
# $list[[38]]$weather[[1]]
# $list[[38]]$weather[[1]]$id
# [1] 804
#
# $list[[38]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[38]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[38]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[38]]$clouds
# $list[[38]]$clouds$all
# [1] 98
#
#
# $list[[38]]$wind
# $list[[38]]$wind$speed
# [1] 1.07
#
# $list[[38]]$wind$deg
# [1] 164
#
# $list[[38]]$wind$gust
# [1] 1.79
#
#
# $list[[38]]$visibility
# [1] 10000
#
# $list[[38]]$pop
# [1] 0
#
# $list[[38]]$sys
# $list[[38]]$sys$pod
# [1] "n"
#
#
# $list[[38]]$dt_txt
# [1] "2022-08-29 12:00:00"
#
#
# $list[[39]]
# $list[[39]]$dt
# [1] 1661785200
#
# $list[[39]]$main
# $list[[39]]$main$temp
# [1] 22.01
#
# $list[[39]]$main$feels_like
# [1] 21.81
#
# $list[[39]]$main$temp_min
# [1] 22.01
#
# $list[[39]]$main$temp_max
# [1] 22.01
#
# $list[[39]]$main$pressure
# [1] 1016
#
# $list[[39]]$main$sea_level
# [1] 1016
#
# $list[[39]]$main$grnd_level
# [1] 1010
#
# $list[[39]]$main$humidity
# [1] 59
#
# $list[[39]]$main$temp_kf
# [1] 0
#
#
# $list[[39]]$weather
# $list[[39]]$weather[[1]]
# $list[[39]]$weather[[1]]$id
# [1] 804
#
# $list[[39]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[39]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[39]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[39]]$clouds
# $list[[39]]$clouds$all
# [1] 100
#
#
# $list[[39]]$wind
# $list[[39]]$wind$speed
# [1] 1.14
#
# $list[[39]]$wind$deg
# [1] 38
#
# $list[[39]]$wind$gust
# [1] 1.75
#
#
# $list[[39]]$visibility
# [1] 10000
#
# $list[[39]]$pop
# [1] 0
#
# $list[[39]]$sys
# $list[[39]]$sys$pod
# [1] "n"
#
#
# $list[[39]]$dt_txt
# [1] "2022-08-29 15:00:00"
#
#
# $list[[40]]
# $list[[40]]$dt
# [1] 1661796000
#
# $list[[40]]$main
# $list[[40]]$main$temp
# [1] 21.49
#
# $list[[40]]$main$feels_like
# [1] 21.31
#
# $list[[40]]$main$temp_min
# [1] 21.49
#
# $list[[40]]$main$temp_max
# [1] 21.49
#
# $list[[40]]$main$pressure
# [1] 1015
#
# $list[[40]]$main$sea_level
# [1] 1015
#
# $list[[40]]$main$grnd_level
# [1] 1009
#
# $list[[40]]$main$humidity
# [1] 62
#
# $list[[40]]$main$temp_kf
# [1] 0
#
#
# $list[[40]]$weather
# $list[[40]]$weather[[1]]
# $list[[40]]$weather[[1]]$id
# [1] 804
#
# $list[[40]]$weather[[1]]$main
# [1] "Clouds"
#
# $list[[40]]$weather[[1]]$description
# [1] "overcast clouds"
#
# $list[[40]]$weather[[1]]$icon
# [1] "04n"
#
#
#
# $list[[40]]$clouds
# $list[[40]]$clouds$all
# [1] 100
#
#
# $list[[40]]$wind
# $list[[40]]$wind$speed
# [1] 0.53
#
# $list[[40]]$wind$deg
# [1] 104
#
# $list[[40]]$wind$gust
# [1] 1.01
#
#
# $list[[40]]$visibility
# [1] 10000
#
# $list[[40]]$pop
# [1] 0
#
# $list[[40]]$sys
# $list[[40]]$sys$pod
# [1] "n"
#
#
# $list[[40]]$dt_txt
# [1] "2022-08-29 18:00:00"
#
#
#
# $city
# $city$id
# [1] 1835848
#
# $city$name
# [1] "Seoul"
#
# $city$coord
# $city$coord$lat
# [1] 37.5683
#
# $city$coord$lon
# [1] 126.9778
#
#
# $city$country
# [1] "KR"
#
# $city$population
# [1] 10349312
#
# $city$timezone
# [1] 32400
#
# $city$sunrise
# [1] 1661374569
#
# $city$sunset
# [1] 1661422376

# %% [markdown]
# It contains very detailed weather data about the city of `Seoul`. Feel free to try other cities as well. We need to convert the named list to a data frame so that we can use data frame operations to process the data. Below is a simple example, which you may implement your own way to convert it to a data frame.

# %%
# Create some empty vectors to hold data temporarily
weather <- c()
visibility <- c()
temp <- c()
temp_min <- c()
temp_max <- c()
pressure <- c()
humidity <- c()
wind_speed <- c()
wind_deg <- c()

# %% [markdown]
# Now assign the values in the `json_result` list into different vectors

# %%
# $weather is also a list with one element, its $main element indicates the weather status such as clear or rain
weather <- c(weather, json_result$weather[[1]]$main)
# Get Visibility
visibility <- c(visibility, json_result$visibility)
# Get current temperature 
temp <- c(temp, json_result$main$temp)
# Get min temperature 
temp_min <- c(temp_min, json_result$main$temp_min)
# Get max temperature 
temp_max <- c(temp_max, json_result$main$temp_max)
# Get pressure
pressure <- c(pressure, json_result$main$pressure)
# Get humidity
humidity <- c(humidity, json_result$main$humidity)
# Get wind speed
wind_speed <- c(wind_speed, json_result$wind$speed)
# Get wind direction
wind_deg <- c(wind_deg, json_result$wind$deg)

# %% [markdown]
# Combine all vectors as columns of a data frame

# %%
# Combine all vectors
weather_data_frame <- data.frame(weather=weather, 
                                 visibility=visibility, 
                                 temp=temp, 
                                 temp_min=temp_min, 
                                 temp_max=temp_max, 
                                 pressure=pressure, 
                                 humidity=humidity, 
                                 wind_speed=wind_speed, 
                                 wind_deg=wind_deg)

# %%
# Check the generated data frame
print(weather_data_frame)
# Out:
#   weather visibility  temp temp_min temp_max pressure humidity wind_speed
# 1   Clear      10000 21.51    20.66    22.69     1007       78       2.06
#   wind_deg
# 1      160

# %% [markdown]
# # TASK:  Get 5-day weather forecasts for a list of cities using the OpenWeather API

# %% [markdown]
# Now you should be familiar with the usage of OpenWeather API. Next, you need to complete a task to get 5-day weather forecasts for a list of cities

# %% [markdown]
# *TODO:* Write a function to return a data frame containing 5-day weather forecasts for a list of cities

# %%
# Create some empty vectors to hold data temporarily

# City name column
city <- c()
# Weather column, rainy or cloudy, etc
weather <- c()
# Sky visibility column
visibility <- c()
# Current temperature column
temp <- c()
# Max temperature column
temp_min <- c()
# Min temperature column
temp_max <- c()
# Pressure column
pressure <- c()
# Humidity column
humidity <- c()
# Wind speed column
wind_speed <- c()
# Wind direction column
wind_deg <- c()
# Forecast timestamp
forecast_datetime <- c()
# Season column
# Note that for season, you can hard code a season value from levels Spring, Summer, Autumn, and Winter based on your current month.
season <- c()

# %%
# Get forecast data for a given city list
get_weather_forecaset_by_cities <- function(city_names){
    df <- data.frame()
    for (citi in city_names){
        your_api_key <- "9948c3bde5327cfdf22d78f34c01714d"
        # Forecast API URL
        forecast_url <- 'https://api.openweathermap.org/data/2.5/forecast'
        # Create query parameters
        forecast_query <- list(q = citi, appid = your_api_key, units="metric")
        
        # Make HTTP GET call for the given city
        forecast_response <- GET(forecast_url, query=forecast_query)
        json_result <- content(forecast_response, as="parsed")
        # Note that the 5-day forecast JSON result is a list of lists. You can print the reponse to check the results
        results <- json_result$list
        
        # Loop the json result
      
        for(result in results) {
                city <- c(city, json_result$city$name)
             weather <- c(weather, result$weather[[1]]$main)
          visibility <- c(visibility, result$visibility) 
                temp <- c(temp, result$main$temp) 
            temp_min <- c(temp_min, result$main$temp_min) 
            temp_max <- c(temp_max, result$main$temp_max)
            pressure <- c(pressure, result$main$pressure)
            humidity <- c(humidity, result$main$humidity)
          wind_speed <- c(wind_speed, result$wind$speed)
            wind_deg <- c(wind_deg, result$wind$deg)
   forecast_datetime <- c(forecast_datetime, result$dt_txt)
              season <- c(season,"Summer")
                
        }
        
        # Add the R Lists into a data frame
                
    }
                df<- data.frame(city=city,
                                 weather=weather, 
                                 visibility=visibility, 
                                 temp=temp, 
                                 temp_min=temp_min, 
                                 temp_max=temp_max, 
                                 pressure=pressure, 
                                 humidity=humidity, 
                                 wind_speed=wind_speed, 
                                 wind_deg=wind_deg,
                                 forecast_datetime=forecast_datetime,
                                 season=season)
                 
                #print(length(weather))
                
    # Return a data frame
    return(df)
    
}

# %% [markdown]
# Complete and call `get_weather_forecaset_by_cities` function with a list of cities, and write the data frame into a csv file called `cities_weather_forecast.csv`

# %%
cities <- c("Seoul", "Washington, D.C.", "Paris", "Suzhou")
cities_weather_df <- get_weather_forecaset_by_cities(cities)

# %%
# Write cities_weather_df to `cities_weather_forecast.csv`
write.csv(cities_weather_df, "cities_weather_forecast.csv", row.names=FALSE)

# %% [markdown]
# For more details about HTTP requests with `httr`, please refer to the previous HTTP request notebook here:
#
# [HTTP request in R](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M4\_Working_With_Data/lab2\_jupyter_http-request.ipynb)

# %% [markdown]
# ## TASK: Download datasets as csv files from cloud storage

# %% [markdown]
# The last task of this lab is straightforward: download some aggregated datasets from cloud storage

# %%
# Download several datasets

# Download some general city information such as name and locations
url <- "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/datasets/raw_worldcities.csv"
# download the file
download.file(url, destfile = "raw_worldcities.csv")

# Download a specific hourly Seoul bike sharing demand dataset
url <- "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/datasets/raw_seoul_bike_sharing.csv"
# download the file
download.file(url, destfile = "raw_seoul_bike_sharing.csv")

# %% [markdown]
# ## Next Step

# %% [markdown]
# Now you should collect all datasets required for this project, all in csv format. Feel free to explore them preliminarily now. However, they are the raw datasets and have to be processed for further data visualization or data analysis.
#
# In the next module, you will improve their quality by performing data wrangling tasks.

# %% [markdown]
# ## Authors
#
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2022-01-01" target="_blank">Yan Luo</a>

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-04-05        | 0.1     | Yan        | Initial version created |
# |                   |         |            |                         |
# |                   |         |            |                         |
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
